# %% [markdown]
# <a href="https://colab.research.google.com/github/EvansWinner01/Data-Science-Project/blob/main/BankApp_Simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Create a bank App
class Bankapp:
    def __init__(self):
        self.balance = 0
        self.pin = "1234"
    def Deposit(self):
        account_no = int(input("Enter your account Number:"))
        amount = int(input("Enter the amount:"))
        self.balance += amount
        print("Transaction Successful...")
    def Transfer(self):
        bank = input("Enter the bank to transfer to : ")
        account_no = int(input("Enter the account number: "))
        amount = int(input("Enter the amount:"))
        if amount > self.balance:
            print("Insufficient Fund..")
        elif amount < 100:
            print("The minimum amount to transfer is 100 naria")
        else:
            pin = input("Enter your pin: ")
            if pin == self.pin:
                self.balance -= amount
                print("\n Transaction Successful..")
            else:
                print("Incorrect pin ")
    def Airtime(self):
        network = input("Enter the desired Network: ")
        phone_no = int(input("Enter the desired Phone number:"))
        amount = int(input("Enter the amount: "))
        if amount > self.balance:
            print("Insufficient Fund..")
        elif amount < 50:
            print("The minimum amount is 50 naria")
        else:
            pin = input("Enter your pin: ")
            if pin == self.pin:
                self.balance -= amount
                print("Your Airtime Purchase was successful...")
            else:
                print("Incorrect Pin ")
    def Electricity(self):
        service_provider = input("Enter your Service Provider Detail: ").upper()
        computer = ["AEDC", "EEDC", "KADC", "PHCN"]
        if service_provider not in computer:
            print("Please Select a Valid Service Provider")
        else:
            package = input("What is your preferred package (Prepaid or Postpaid)?: ")
            meter_no = input("Enter your meter number: ")
            amount = int(input("Enter amount to recharge: "))
            if amount > self.balance:
                print("Insufficient Funds.")
            elif amount < 1000:
                print("The minimum amount to recharge is 1000")
                pin = input("Enter your pin: ")
                if pin == self.pin:
                    self.balance -= amount
                    print("Recharge Successful")
                else:
                    print("Incorrect pin")
    def Check_balance(self):
        pin = input("Enter your Pin: ")
        if pin == self.pin:
            account_no = int(input("Enter your account number: "))
            print(f"Your account balance is {self.balance} naira")
        else:
            print("Incorrect Pin")

def main():
    bankapp = Bankapp()
    while True:
        print("\n     Welcome to Earlycode Bank PLc     ")
        print("1 << Deposit")
        print("2 << Transfer")
        print("3 << Airtime ")
        print("4 << Electricity")
        print("5 << Balance")
        print("6 << Logout ")
        option = input("Select an option: ")
        if option == "1":
            bankapp.Deposit()
        elif option == "2":
            bankapp.Transfer()
        elif option == "3":
            bankapp.Airtime()
        elif option == "4":
            bankapp.Electricity()
        elif option == "5":
            bankapp.Check_balance()
        elif option == "6":
            print("Thank you for banking with us..")
            break
        else:
            print("Invaild selection, Please try again..")
if __name__ == "__main__":
    main()
# Out:
#      Welcome to Earlycode Bank PLc
# 1 << Deposit
# 2 << Transfer
# 3 << Airtime
# 4 << Electricity
# 5 << Balance
# 6 << Logout
# Select an option: 1
# Enter your account Number:123345678
# Enter the amount:5000
# Transaction Successful...
#
#      Welcome to Earlycode Bank PLc
# 1 << Deposit
# 2 << Transfer
# 3 << Airtime
# 4 << Electricity
# 5 << Balance
# 6 << Logout
# Select an option: 4
# Enter your Service Provider Detail: Aedc
# What is your preferred package (Prepaid or Postpaid)?: Prepaid
# Enter your meter number: 478906
# Enter amount to recharge: 40000
# Insufficient Funds.
#
#      Welcome to Earlycode Bank PLc
# 1 << Deposit
# 2 << Transfer
# 3 << Airtime
# 4 << Electricity
# 5 << Balance
# 6 << Logout
# Select an option: 6
# Thank you for banking with us..
